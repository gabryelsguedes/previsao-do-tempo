# %%
import pandas as pd
import numpy as np 
import joblib

from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.pipeline import Pipeline
from sklearn.model_selection import TimeSeriesSplit,GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression,Lasso,Ridge  
from sklearn.neighbors import KNeighborsRegressor 
from sklearn.tree import DecisionTreeRegressor 
from xgboost import XGBRegressor 
from sklearn.svm import SVR 
from sklearn.neural_network import MLPRegressor

from sklearn.metrics import make_scorer

# %% [markdown]
# ## Tratamento dos Dados
#
# ##### Como nosso objetivo é predizer a temperatura duas horas a frente, precisamos que nosso modelo consiga fazer a predição da temperatura futura. <br><br> Para tal, foi criada uma nova coluna utilizando a função shift para deslizar todos os valores duas horas à frente. Essa coluna é adicionada ao dataframe e a mesma será o valor a ser predito.

# %%
df_temperatura = pd.read_csv("..\db\clima_tratado.csv", sep=',')

# %%
df_temperatura['temp_lag_2'] = df_temperatura['T (degC)'].shift(2)
df_temperatura = df_temperatura.dropna(axis=0)
df_temperatura
# Out:
#                   DateTime  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 2      2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66   93.50
# 3      2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02   92.60
# 4      2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65   92.20
# 5      2009-01-01 06:00:00    997.71     -9.67    263.66       -10.62   92.70
# 6      2009-01-01 07:00:00    998.33     -9.17    264.12       -10.10   92.90
# ...                    ...       ...       ...       ...          ...     ...
# 70087  2016-12-31 20:00:00   1001.47     -1.52    271.52        -7.13   65.42
# 70088  2016-12-31 21:00:00   1001.29     -3.09    269.98        -7.09   73.70
# 70089  2016-12-31 22:00:00   1000.70     -2.59    270.51        -7.04   71.30
# 70090  2016-12-31 23:00:00   1000.21     -3.76    269.39        -7.95   72.50
# 70091  2017-01-01 00:00:00    999.82     -4.82    268.36        -8.42   75.70
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 2              3.13          2.93          0.20       1.83             2.94
# 3              3.07          2.85          0.23       1.78             2.85
# 4              2.94          2.71          0.23       1.69             2.71
# 5              2.93          2.71          0.21       1.69             2.72
# 6              3.04          2.83          0.22       1.76             2.83
# ...             ...           ...           ...        ...              ...
# 70087          5.46          3.57          1.89       2.22             3.57
# 70088          4.86          3.58          1.28       2.23             3.58
# 70089          5.04          3.60          1.45       2.24             3.59
# 70090          4.62          3.35          1.27       2.09             3.35
# 70091          4.27          3.23          1.04       2.01             3.23
#
#        rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)  temp_lag_2
# 2           1312.18      0.18           0.63    167.20       -8.05
# 3           1313.61      0.10           0.38    240.00       -8.88
# 4           1317.19      0.40           0.88    157.00       -8.81
# 5           1317.71      0.05           0.50    146.00       -9.05
# 6           1315.98      2.08           2.88    348.80       -9.63
# ...             ...       ...            ...       ...         ...
# 70087       1282.60      1.24           1.96    232.00       -0.08
# 70088       1289.78      0.61           1.48    207.50       -1.03
# 70089       1286.67      0.38           0.72      8.15       -1.52
# 70090       1291.71      0.89           1.30    223.70       -3.09
# 70091       1296.38      1.23           1.96    184.90       -2.59
#
# [70090 rows x 16 columns]

# %%
df_temperatura.set_index('DateTime',inplace=True)
df_temperatura
# Out:
#                      p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# DateTime
# 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66   93.50
# 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02   92.60
# 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65   92.20
# 2009-01-01 06:00:00    997.71     -9.67    263.66       -10.62   92.70
# 2009-01-01 07:00:00    998.33     -9.17    264.12       -10.10   92.90
# ...                       ...       ...       ...          ...     ...
# 2016-12-31 20:00:00   1001.47     -1.52    271.52        -7.13   65.42
# 2016-12-31 21:00:00   1001.29     -3.09    269.98        -7.09   73.70
# 2016-12-31 22:00:00   1000.70     -2.59    270.51        -7.04   71.30
# 2016-12-31 23:00:00   1000.21     -3.76    269.39        -7.95   72.50
# 2017-01-01 00:00:00    999.82     -4.82    268.36        -8.42   75.70
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# DateTime
# 2009-01-01 03:00:00          3.13          2.93          0.20       1.83
# 2009-01-01 04:00:00          3.07          2.85          0.23       1.78
# 2009-01-01 05:00:00          2.94          2.71          0.23       1.69
# 2009-01-01 06:00:00          2.93          2.71          0.21       1.69
# 2009-01-01 07:00:00          3.04          2.83          0.22       1.76
# ...                           ...           ...           ...        ...
# 2016-12-31 20:00:00          5.46          3.57          1.89       2.22
# 2016-12-31 21:00:00          4.86          3.58          1.28       2.23
# 2016-12-31 22:00:00          5.04          3.60          1.45       2.24
# 2016-12-31 23:00:00          4.62          3.35          1.27       2.09
# 2017-01-01 00:00:00          4.27          3.23          1.04       2.01
#
#                      H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  \
# DateTime
# 2009-01-01 03:00:00             2.94       1312.18      0.18           0.63
# 2009-01-01 04:00:00             2.85       1313.61      0.10           0.38
# 2009-01-01 05:00:00             2.71       1317.19      0.40           0.88
# 2009-01-01 06:00:00             2.72       1317.71      0.05           0.50
# 2009-01-01 07:00:00             2.83       1315.98      2.08           2.88
# ...                              ...           ...       ...            ...
# 2016-12-31 20:00:00             3.57       1282.60      1.24           1.96
# 2016-12-31 21:00:00             3.58       1289.78      0.61           1.48
# 2016-12-31 22:00:00             3.59       1286.67      0.38           0.72
# 2016-12-31 23:00:00             3.35       1291.71      0.89           1.30
# 2017-01-01 00:00:00             3.23       1296.38      1.23           1.96
#
#                      wd (deg)  temp_lag_2
# DateTime
# 2009-01-01 03:00:00    167.20       -8.05
# 2009-01-01 04:00:00    240.00       -8.88
# 2009-01-01 05:00:00    157.00       -8.81
# 2009-01-01 06:00:00    146.00       -9.05
# 2009-01-01 07:00:00    348.80       -9.63
# ...                       ...         ...
# 2016-12-31 20:00:00    232.00       -0.08
# 2016-12-31 21:00:00    207.50       -1.03
# 2016-12-31 22:00:00      8.15       -1.52
# 2016-12-31 23:00:00    223.70       -3.09
# 2017-01-01 00:00:00    184.90       -2.59
#
# [70090 rows x 15 columns]

# %% [markdown]
# ##### Separação da coluna com as entradas e os valores de saída

# %%
#Separando as colunas
X = df_temperatura.drop(['temp_lag_2'],axis=1)
Y = df_temperatura['temp_lag_2'].ravel()

# %% [markdown]
# #### Utilização de uma normalização com as variáveis de entrada para que evitar a ocorrência de alguns atributos terem o peso maior do que outros

# %%
#Definindo a normalização utilizada
preprocessing = MinMaxScaler(feature_range=(0,1))

# %% [markdown]
# #### As métricas utilizados para avaliar o desempenho dos modelos de regressão foram:
#
# - **MAE** (Erro Absoluto Médio): calcula o "erro absoluto médio" dos erros entre valores observados (reais) e predições (hipóteses). Quanto maior seu valor, pior o desempenho do modelo.
# - **MSE** (Erro quadrado médio): Mede o erro ao quadrado médio das previsões do modelo. MSE calcula a diferença ao quadrado entre o resultado observado (real) e os valores previstos e depois calcula a média. Quanto maior seu valor, pior o desempenho do modelo.
# - **R²**: expressa a porcentagem de variância explicada pelas variáveis independentes apresentadas no modelo. Quando maior, melhor o desempenho dele. <br>

# %%
#Definindo as metricas utilizadas para comparar os modelos 
mse_scorer = make_scorer(mean_squared_error,greater_is_better=False)
mae_scorer = make_scorer(mean_absolute_error,greater_is_better=False)
r2_scorer = make_scorer(r2_score,greater_is_better=True)

metricas = {'mse':mean_squared_error, 'mae':mean_absolute_error,'r2':r2_score}
metricas2 = {'mse':mse_scorer, 'mae':mae_scorer,'r2':r2_scorer}

# %% [markdown]
# ##### Os  modelos escolhidos foram:
# - **Regressão Linear**;
# - **Regressão Ridge**;
# - **Regressão Lasso**;
# - **KNN**;
# - **Árvore de Decisão**;
# - **Gradient Boosting**.
# - **Random Forest**;
# - **SVM**;
# - **Redes Neurais**;
#
# ##### Foram também definidos alguns hiperparâmetros para cada modelo a fim de, através da busca em grade, encontrar os melhores valores para o melhor desempenho de cada modelo.

# %%
#Definição dos modelos e parametros utilizados por cada um deles
model = [
    ('RandomForestRegressor', RandomForestRegressor()),
    ('LinearRegression', LinearRegression()),
    ('Ridge', Ridge()),
    ('Lasso', Lasso()),
    ('SVR', SVR()),
    ('MLPRegressor',MLPRegressor()),
    ('XGBoost',XGBRegressor()),
    ('DecisionTreeRegressor',DecisionTreeRegressor()),
    ('KNeighborsRegressor',KNeighborsRegressor())
    
]

param_grid = [
    {
        'model': [RandomForestRegressor()],
        'model__n_estimators': [10, 50, 100],
        'model__max_depth': [5, 10, 15]
    },
    {
        'model': [LinearRegression()],
        'model__fit_intercept': [True, False]
    },
    {
        'model': [Ridge()],
        'model__alpha': [0.1, 0.5, 1.0]
    },
    {
        'model': [Lasso()],
        'model__alpha': [0.1, 0.5, 1.0]
    },
    {
        'model': [SVR()],
        'model__C': [0.1, 1.0, 10.0],
        'model__kernel': ['linear', 'poly', 'rbf']
    },
    {
        'model': [MLPRegressor()],
        'model__hidden_layer_sizes': [(10,), (50,), (100,)],
        'model__activation': ['identity', 'logistic', 'tanh', 'relu'],
        'model__max_iter': [1000]
    },
    {   'model':[XGBRegressor()],
        'model__learning_rate': [0.05, 0.1, 0.2],
        'model__n_estimators' : [100, 200, 300, 500],
        'model__max_depth'    : [5, 10, 20, 30, 40],
        'model__min_child_weight': [1, 3, 5, 10]
    },
    {   'model': [DecisionTreeRegressor()],
        "model__splitter":["best","random"],
        "model__max_depth" : [3,5,8,10,15],
        "model__max_leaf_nodes":[None,10,20,30,40,50,60],
        "model__min_samples_leaf": np.linspace(0.1, 0.5, 6),
        "model__max_features": ["log2", "sqrt"],
        "model__criterion": ["friedman_mse", "squared_error"]
    },
    {   'model': [KNeighborsRegressor()],
        'model__n_neighbors': np.arange(3, 17, 2),
        'model__weights': ['uniform', 'distance'],
        'model__metric': ['euclidean', 'manhattan'],
        'model__leaf_size': [10, 20, 30, 40, 50]
    }
]

# %%
#Criação do pipeline
pipe = Pipeline([
    ('preprocesing',preprocessing),
    ('model',model)
])

# %%
#Criação dos parametros de busca por grade para encontrar o melhor modelo e parametros
grid = GridSearchCV(pipe, param_grid, cv=TimeSeriesSplit(n_splits=3), scoring=metricas2,refit='r2', return_train_score=True, verbose=3)

# %%
#Divisão em treino e teste
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,shuffle=False)
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (56072, 14) (14018, 14) (56072,) (14018,)

# %%
#Treinamento dos modelos
grid.fit(X_train,Y_train)
# Out:
# Fitting 3 folds for each of 2098 candidates, totalling 6294 fits
# [CV 1/3] END model=RandomForestRegressor(), model__max_depth=5, model__n_estimators=10; mae: (train=-1.276, test=-1.266) mse: (train=-3.138, test=-3.214) r2: (train=0.962, test=0.956) total time=   0.5s
# [CV 2/3] END model=RandomForestRegressor(), model__max_depth=5, model__n_estimators=10; mae: (train=-1.268, test=-1.304) mse: (train=-3.162, test=-3.272) r2: (train=0.960, test=0.954) total time=   1.0s
# [CV 3/3] END model=RandomForestRegressor(), model__max_depth=5, model__n_estimators=10; mae: (train=-1.273, test=-1.233) mse: (train=-3.184, test=-3.023) r2: (train=0.959, test=0.941) total time=   1.6s
# [CV 1/3] END model=RandomForestRegressor(), model__max_depth=5, model__n_estimators=50; mae: (train=-1.265, test=-1.260) mse: (train=-3.100, test=-3.179) r2: (train=0.963, test=0.957) total time=   2.7s
# [CV 2/3] END model=RandomForestRegressor(), model__max_depth=5, model__n_estimators=50; mae: (train=-1.263, test=-1.301) mse: (train=-3.142, test=-3.250) r2: (train=0.960, test=0.955) total time=   4.9s
# [CV 3/3] END model=RandomForestRegressor(), model__max_depth=5, model__n_estimators=50; mae: (train=-1.277, test=-1.237) mse: (train=-3.193, test=-3.032) r2: (train=0.959, test=0.940) total time=   7.2s
# [CV 1/3] END model=RandomForestRegressor(), model__max_depth=5, model__n_estimators=100; mae: (train=-1.267, test=-1.261) mse: (train=-3.107, test=-3.184) r2: (train=0.962, test=0.957) total time=   5.9s
# [CV 2/3] END model=RandomForestRegressor(), model__max_depth=5, model__n_estimators=100; mae: (train=-1.263, test=-1.299) mse: (train=-3.145, test=-3.250) r2: (train=0.960, test=0.955) total time=  10.6s
# [CV 3/3] END model=RandomForestRegressor(), model__max_depth=5, model__n_estimators=100; mae: (train=-1.272, test=-1.234) mse: (train=-3.178, test=-3.020) r2: (train=0.959, test=0.941) total time=  15.4s
# [CV 1/3] END model=RandomForestRegressor(), model__max_depth=10, model__n_estimators=10; mae: (train=-0.909, test=-1.207) mse: (train=-1.542, test=-2.804) r2: (train=0.981, test=0.962) total time=   1.2s
# [CV 2/3] END model=RandomForestRegressor(), model__max_depth=10, model__n_estimators=10; mae: (train=-0.977, test=-1.170) mse: (train=-1.818, test=-2.674) r2: (train=0.977, test=0.963) total time=   2.3s
# [CV 3/3] END model=RandomForestRegressor(), model__max_depth=10, model__n_estimators=10; mae: (train=-1.012, test=-1.120) mse: (train=-1.964, test=-2.448) r2: (train=0.975, test=0.952) total time=   3.3s
# [CV 1/3] END model=RandomForestRegressor(), model__max_depth=10, model__n_estimators=50; mae: (train=-0.893, test=-1.186) mse: (train=-1.478, test=-2.732) r2: (train=0.982, test=0.963) total time=   6.1s
# [CV 2/3] END model=RandomForestRegressor(), model__max_depth=10, model__n_estimators=50; mae: (train=-0.965, test=-1.150) mse: (train=-1.760, test=-2.590) r2: (train=0.978, test=0.964) total time=  11.5s
# [CV 3/3] END model=RandomForestRegressor(), model__max_depth=10, model__n_estimators=50; mae: (train=-1.003, test=-1.108) mse: (train=-1.921, test=-2.398) r2: (train=0.975, test=0.953) total time=  16.8s
# [CV 1/3] END model=RandomForestRegressor(), model__max_depth=10, model__n_estimators=100; mae: (train=-0.889, test=-1.178) mse: (train=-1.468, test=-2.701) r2: (train=0.982, test=0.963) total time=  12.6s
# [CV 2/3] END model=RandomForestRegressor(), model__max_depth=10, model__n_estimators=100; mae: (train=-0.965, test=-1.148) mse: (train=-1.759, test=-2.580) r2: (train=0.978, test=0.964) total time=  23.4s
# [CV 3/3] END model=RandomForestRegressor(), model__max_depth=10, model__n_estimators=100; mae: (train=-1.002, test=-1.108) mse: (train=-1.914, test=-2.400) r2: (train=0.975, test=0.953) total time=  33.8s
# [CV 1/3] END model=RandomForestRegressor(), model__max_depth=15, model__n_estimators=10; mae: (train=-0.580, test=-1.246) mse: (train=-0.651, test=-2.967) r2: (train=0.992, test=0.960) total time=   1.8s
# [CV 2/3] END model=RandomForestRegressor(), model__max_depth=15, model__n_estimators=10; mae: (train=-0.650, test=-1.214) mse: (train=-0.796, test=-2.877) r2: (train=0.990, test=0.960) total time=   3.5s
# [CV 3/3] END model=RandomForestRegressor(), model__max_depth=15, model__n_estimators=10; mae: (train=-0.686, test=-1.162) mse: (train=-0.882, test=-2.585) r2: (train=0.989, test=0.949) total time=   5.3s
# [CV 1/3] END model=RandomForestRegressor(), model__max_depth=15, model__n_estimators=50; mae: (train=-0.546, test=-1.195) mse: (train=-0.541, test=-2.755) r2: (train=0.993, test=0.963) total time=   9.1s
# [CV 2/3] END model=RandomForestRegressor(), model__max_depth=15, model__n_estimators=50; mae: (train=-0.619, test=-1.163) mse: (train=-0.683, test=-2.656) r2: (train=0.991, test=0.963) total time=  17.3s
# [CV 3/3] END model=RandomForestRegressor(), model__max_depth=15, model__n_estimators=50; mae: (train=-0.656, test=-1.119) mse: (train=-0.774, test=-2.432) r2: (train=0.990, test=0.952) total time=  26.4s
# [CV 1/3] END model=RandomForestRegressor(), model__max_depth=15, model__n_estimators=100; mae: (train=-0.538, test=-1.194) mse: (train=-0.521, test=-2.748) r2: (train=0.994, test=0.963) total time=  18.8s
# [CV 2/3] END model=RandomForestRegressor(), model__max_depth=15, model__n_estimators=100; mae: (train=-0.612, test=-1.151) mse: (train=-0.666, test=-2.600) r2: (train=0.992, test=0.964) total time=  35.0s
# [CV 3/3] END model=RandomForestRegressor(), model__max_depth=15, model__n_estimators=100; mae: (train=-0.652, test=-1.114) mse: (train=-0.759, test=-2.412) r2: (train=0.990, test=0.953) total time=  53.1s
# [CV 1/3] END model=LinearRegression(), model__fit_intercept=True; mae: (train=-1.256, test=-1.224) mse: (train=-3.110, test=-3.053) r2: (train=0.962, test=0.959) total time=   0.0s
# [CV 2/3] END model=LinearRegression(), model__fit_intercept=True; mae: (train=-1.241, test=-1.248) mse: (train=-3.077, test=-3.033) r2: (train=0.961, test=0.958) total time=   0.0s
# [CV 3/3] END model=LinearRegression(), model__fit_intercept=True; mae: (train=-1.241, test=-1.192) mse: (train=-3.060, test=-2.861) r2: (train=0.961, test=0.944) total time=   0.0s
# [CV 1/3] END model=LinearRegression(), model__fit_intercept=False; mae: (train=-1.258, test=-1.226) mse: (train=-3.115, test=-3.061) r2: (train=0.962, test=0.959) total time=   0.0s
# [CV 2/3] END model=LinearRegression(), model__fit_intercept=False; mae: (train=-1.243, test=-1.248) mse: (train=-3.082, test=-3.033) r2: (train=0.961, test=0.958) total time=   0.0s
# [CV 3/3] END model=LinearRegression(), model__fit_intercept=False; mae: (train=-1.242, test=-1.193) mse: (train=-3.063, test=-2.866) r2: (train=0.961, test=0.944) total time=   0.0s
# [CV 1/3] END model=Ridge(), model__alpha=0.1; mae: (train=-1.255, test=-1.224) mse: (train=-3.116, test=-3.058) r2: (train=0.962, test=0.959) total time=   0.0s
# [CV 2/3] END model=Ridge(), model__alpha=0.1; mae: (train=-1.241, test=-1.244) mse: (train=-3.081, test=-3.029) r2: (train=0.961, test=0.958) total time=   0.0s
# [CV 3/3] END model=Ridge(), model__alpha=0.1; mae: (train=-1.240, test=-1.191) mse: (train=-3.062, test=-2.860) r2: (train=0.961, test=0.944) total time=   0.0s
# [CV 1/3] END model=Ridge(), model__alpha=0.5; mae: (train=-1.254, test=-1.223) mse: (train=-3.124, test=-3.064) r2: (train=0.962, test=0.958) total time=   0.0s
# [CV 2/3] END model=Ridge(), model__alpha=0.5; mae: (train=-1.240, test=-1.243) mse: (train=-3.087, test=-3.033) r2: (train=0.961, test=0.958) total time=   0.0s
# [CV 3/3] END model=Ridge(), model__alpha=0.5; mae: (train=-1.240, test=-1.190) mse: (train=-3.066, test=-2.861) r2: (train=0.961, test=0.944) total time=   0.0s
# [CV 1/3] END model=Ridge(), model__alpha=1.0; mae: (train=-1.254, test=-1.223) mse: (train=-3.130, test=-3.070) r2: (train=0.962, test=0.958) total time=   0.0s
# [CV 2/3] END model=Ridge(), model__alpha=1.0; mae: (train=-1.240, test=-1.243) mse: (train=-3.091, test=-3.037) r2: (train=0.961, test=0.958) total time=   0.0s
# [CV 3/3] END model=Ridge(), model__alpha=1.0; mae: (train=-1.239, test=-1.190) mse: (train=-3.069, test=-2.862) r2: (train=0.961, test=0.944) total time=   0.0s
# [CV 1/3] END model=Lasso(), model__alpha=0.1; mae: (train=-1.425, test=-1.376) mse: (train=-3.655, test=-3.536) r2: (train=0.956, test=0.952) total time=   0.0s
# [CV 2/3] END model=Lasso(), model__alpha=0.1; mae: (train=-1.412, test=-1.420) mse: (train=-3.639, test=-3.580) r2: (train=0.954, test=0.950) total time=   0.0s
# [CV 3/3] END model=Lasso(), model__alpha=0.1; mae: (train=-1.423, test=-1.322) mse: (train=-3.640, test=-3.216) r2: (train=0.953, test=0.937) total time=   0.0s
# [CV 1/3] END model=Lasso(), model__alpha=0.5; mae: (train=-2.908, test=-2.760) mse: (train=-13.435, test=-12.319) r2: (train=0.838, test=0.833) total time=   0.0s
# [CV 2/3] END model=Lasso(), model__alpha=0.5; mae: (train=-2.954, test=-2.955) mse: (train=-13.864, test=-13.556) r2: (train=0.823, test=0.810) total time=   0.0s
# [CV 3/3] END model=Lasso(), model__alpha=0.5; mae: (train=-3.040, test=-2.554) mse: (train=-14.149, test=-9.775) r2: (train=0.819, test=0.808) total time=   0.0s
# [CV 1/3] END model=Lasso(), model__alpha=1.0; mae: (train=-5.287, test=-4.975) mse: (train=-44.009, test=-39.930) r2: (train=0.468, test=0.459) total time=   0.0s
# [CV 2/3] END model=Lasso(), model__alpha=1.0; mae: (train=-5.409, test=-5.465) mse: (train=-45.815, test=-45.086) r2: (train=0.417, test=0.369) total time=   0.0s
# [CV 3/3] END model=Lasso(), model__alpha=1.0; mae: (train=-5.565, test=-4.585) mse: (train=-46.755, test=-30.661) r2: (train=0.401, test=0.397) total time=   0.0s
# [CV 1/3] END model=SVR(), model__C=0.1, model__kernel=linear; mae: (train=-1.285, test=-1.256) mse: (train=-3.291, test=-3.246) r2: (train=0.960, test=0.956) total time=   9.2s
# [CV 2/3] END model=SVR(), model__C=0.1, model__kernel=linear; mae: (train=-1.247, test=-1.247) mse: (train=-3.192, test=-3.135) r2: (train=0.959, test=0.956) total time=  36.1s
# [CV 3/3] END model=SVR(), model__C=0.1, model__kernel=linear; mae: (train=-1.241, test=-1.191) mse: (train=-3.154, test=-2.934) r2: (train=0.960, test=0.942) total time= 1.2min
# [CV 1/3] END model=SVR(), model__C=0.1, model__kernel=poly; mae: (train=-1.219, test=-1.196) mse: (train=-3.032, test=-3.009) r2: (train=0.963, test=0.959) total time=  12.5s
# [CV 2/3] END model=SVR(), model__C=0.1, model__kernel=poly; mae: (train=-1.197, test=-1.190) mse: (train=-2.963, test=-2.856) r2: (train=0.962, test=0.960) total time=  42.9s
# [CV 3/3] END model=SVR(), model__C=0.1, model__kernel=poly; mae: (train=-1.184, test=-1.143) mse: (train=-2.899, test=-2.709) r2: (train=0.963, test=0.947) total time= 1.7min
# [CV 1/3] END model=SVR(), model__C=0.1, model__kernel=rbf; mae: (train=-1.385, test=-1.384) mse: (train=-4.095, test=-4.259) r2: (train=0.950, test=0.942) total time=  29.6s
# [CV 2/3] END model=SVR(), model__C=0.1, model__kernel=rbf; mae: (train=-1.282, test=-1.306) mse: (train=-3.416, test=-3.740) r2: (train=0.957, test=0.948) total time= 1.4min
# [CV 3/3] END model=SVR(), model__C=0.1, model__kernel=rbf; mae: (train=-1.246, test=-1.175) mse: (train=-3.217, test=-2.870) r2: (train=0.959, test=0.944) total time= 2.3min
# [CV 1/3] END model=SVR(), model__C=1.0, model__kernel=linear; mae: (train=-1.248, test=-1.219) mse: (train=-3.172, test=-3.130) r2: (train=0.962, test=0.958) total time=   9.6s
# [CV 2/3] END model=SVR(), model__C=1.0, model__kernel=linear; mae: (train=-1.232, test=-1.233) mse: (train=-3.140, test=-3.069) r2: (train=0.960, test=0.957) total time=  28.3s
# [CV 3/3] END model=SVR(), model__C=1.0, model__kernel=linear; mae: (train=-1.232, test=-1.186) mse: (train=-3.117, test=-2.918) r2: (train=0.960, test=0.943) total time= 1.3min
# [CV 1/3] END model=SVR(), model__C=1.0, model__kernel=poly; mae: (train=-1.170, test=-1.170) mse: (train=-2.851, test=-2.886) r2: (train=0.966, test=0.961) total time=  13.5s
# [CV 2/3] END model=SVR(), model__C=1.0, model__kernel=poly; mae: (train=-1.164, test=-1.161) mse: (train=-2.822, test=-2.731) r2: (train=0.964, test=0.962) total time=  47.6s
# [CV 3/3] END model=SVR(), model__C=1.0, model__kernel=poly; mae: (train=-1.157, test=-1.117) mse: (train=-2.783, test=-2.621) r2: (train=0.964, test=0.948) total time= 2.0min
# [CV 1/3] END model=SVR(), model__C=1.0, model__kernel=rbf; mae: (train=-1.178, test=-1.183) mse: (train=-2.849, test=-2.908) r2: (train=0.966, test=0.961) total time=  29.8s
# [CV 2/3] END model=SVR(), model__C=1.0, model__kernel=rbf; mae: (train=-1.162, test=-1.172) mse: (train=-2.782, test=-2.791) r2: (train=0.965, test=0.961) total time= 1.2min
# [CV 3/3] END model=SVR(), model__C=1.0, model__kernel=rbf; mae: (train=-1.150, test=-1.111) mse: (train=-2.715, test=-2.574) r2: (train=0.965, test=0.949) total time= 2.2min
# [CV 1/3] END model=SVR(), model__C=10.0, model__kernel=linear; mae: (train=-1.247, test=-1.219) mse: (train=-3.163, test=-3.124) r2: (train=0.962, test=0.958) total time=   9.3s
# [CV 2/3] END model=SVR(), model__C=10.0, model__kernel=linear; mae: (train=-1.231, test=-1.232) mse: (train=-3.128, test=-3.054) r2: (train=0.960, test=0.957) total time=  41.4s
# [CV 3/3] END model=SVR(), model__C=10.0, model__kernel=linear; mae: (train=-1.231, test=-1.185) mse: (train=-3.108, test=-2.913) r2: (train=0.960, test=0.943) total time= 1.4min
# [CV 1/3] END model=SVR(), model__C=10.0, model__kernel=poly; mae: (train=-1.152, test=-1.163) mse: (train=-2.783, test=-2.842) r2: (train=0.966, test=0.961) total time=  39.0s
# [CV 2/3] END model=SVR(), model__C=10.0, model__kernel=poly; mae: (train=-1.150, test=-1.146) mse: (train=-2.759, test=-2.671) r2: (train=0.965, test=0.963) total time= 2.2min
# [CV 3/3] END model=SVR(), model__C=10.0, model__kernel=poly; mae: (train=-1.144, test=-1.111) mse: (train=-2.724, test=-2.600) r2: (train=0.965, test=0.949) total time= 5.7min
# [CV 1/3] END model=SVR(), model__C=10.0, model__kernel=rbf; mae: (train=-1.126, test=-1.154) mse: (train=-2.627, test=-2.724) r2: (train=0.968, test=0.963) total time=  23.6s
# [CV 2/3] END model=SVR(), model__C=10.0, model__kernel=rbf; mae: (train=-1.128, test=-1.134) mse: (train=-2.624, test=-2.591) r2: (train=0.967, test=0.964) total time= 1.1min
# [CV 3/3] END model=SVR(), model__C=10.0, model__kernel=rbf; mae: (train=-1.120, test=-1.096) mse: (train=-2.581, test=-2.477) r2: (train=0.967, test=0.951) total time= 2.1min
# [CV 1/3] END model=MLPRegressor(), model__activation=identity, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.253, test=-1.220) mse: (train=-3.143, test=-3.084) r2: (train=0.962, test=0.958) total time=   2.3s
# [CV 2/3] END model=MLPRegressor(), model__activation=identity, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.239, test=-1.240) mse: (train=-3.114, test=-3.051) r2: (train=0.960, test=0.957) total time=   3.7s
# [CV 3/3] END model=MLPRegressor(), model__activation=identity, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.239, test=-1.188) mse: (train=-3.094, test=-2.882) r2: (train=0.960, test=0.943) total time=   4.1s
# [CV 1/3] END model=MLPRegressor(), model__activation=identity, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.253, test=-1.222) mse: (train=-3.143, test=-3.088) r2: (train=0.962, test=0.958) total time=   3.1s
# [CV 2/3] END model=MLPRegressor(), model__activation=identity, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.244, test=-1.247) mse: (train=-3.109, test=-3.052) r2: (train=0.960, test=0.957) total time=   4.3s
# [CV 3/3] END model=MLPRegressor(), model__activation=identity, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.246, test=-1.196) mse: (train=-3.091, test=-2.874) r2: (train=0.960, test=0.943) total time=   5.5s
# [CV 1/3] END model=MLPRegressor(), model__activation=identity, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.255, test=-1.221) mse: (train=-3.155, test=-3.093) r2: (train=0.962, test=0.958) total time=   3.6s
# [CV 2/3] END model=MLPRegressor(), model__activation=identity, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.239, test=-1.240) mse: (train=-3.117, test=-3.055) r2: (train=0.960, test=0.957) total time=   5.1s
# [CV 3/3] END model=MLPRegressor(), model__activation=identity, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.242, test=-1.191) mse: (train=-3.085, test=-2.869) r2: (train=0.960, test=0.944) total time=   6.2s
# c:\Users\gabry\OneDrive\Documentos\Meus_Projetos\Challenge - FIEC\fiec\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 1/3] END model=MLPRegressor(), model__activation=logistic, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.224, test=-1.205) mse: (train=-2.934, test=-2.911) r2: (train=0.965, test=0.961) total time=  20.1s
# [CV 2/3] END model=MLPRegressor(), model__activation=logistic, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.201, test=-1.206) mse: (train=-2.819, test=-2.783) r2: (train=0.964, test=0.961) total time=  24.8s
# [CV 3/3] END model=MLPRegressor(), model__activation=logistic, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.187, test=-1.150) mse: (train=-2.763, test=-2.618) r2: (train=0.965, test=0.948) total time=  47.1s
# c:\Users\gabry\OneDrive\Documentos\Meus_Projetos\Challenge - FIEC\fiec\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:684: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [CV 1/3] END model=MLPRegressor(), model__activation=logistic, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.192, test=-1.191) mse: (train=-2.703, test=-2.755) r2: (train=0.967, test=0.963) total time=  59.9s
# [CV 2/3] END model=MLPRegressor(), model__activation=logistic, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.201, test=-1.207) mse: (train=-2.806, test=-2.765) r2: (train=0.964, test=0.961) total time=  44.1s
# [CV 3/3] END model=MLPRegressor(), model__activation=logistic, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.157, test=-1.123) mse: (train=-2.561, test=-2.417) r2: (train=0.967, test=0.952) total time= 2.2min
# [CV 1/3] END model=MLPRegressor(), model__activation=logistic, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.251, test=-1.221) mse: (train=-3.085, test=-3.036) r2: (train=0.963, test=0.959) total time=  20.0s
# [CV 2/3] END model=MLPRegressor(), model__activation=logistic, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.169, test=-1.168) mse: (train=-2.619, test=-2.574) r2: (train=0.967, test=0.964) total time= 2.8min
# [CV 3/3] END model=MLPRegressor(), model__activation=logistic, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.170, test=-1.132) mse: (train=-2.658, test=-2.518) r2: (train=0.966, test=0.950) total time= 2.9min
# [CV 1/3] END model=MLPRegressor(), model__activation=tanh, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.240, test=-1.212) mse: (train=-3.080, test=-3.052) r2: (train=0.963, test=0.959) total time=   2.7s
# [CV 2/3] END model=MLPRegressor(), model__activation=tanh, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.202, test=-1.209) mse: (train=-2.805, test=-2.783) r2: (train=0.964, test=0.961) total time=  15.1s
# [CV 3/3] END model=MLPRegressor(), model__activation=tanh, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.159, test=-1.124) mse: (train=-2.584, test=-2.442) r2: (train=0.967, test=0.952) total time=  47.8s
# [CV 1/3] END model=MLPRegressor(), model__activation=tanh, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.202, test=-1.184) mse: (train=-2.776, test=-2.777) r2: (train=0.966, test=0.962) total time=  19.1s
# [CV 2/3] END model=MLPRegressor(), model__activation=tanh, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.153, test=-1.150) mse: (train=-2.555, test=-2.515) r2: (train=0.967, test=0.965) total time=  42.9s
# [CV 3/3] END model=MLPRegressor(), model__activation=tanh, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.147, test=-1.113) mse: (train=-2.527, test=-2.391) r2: (train=0.968, test=0.953) total time=  47.3s
# [CV 1/3] END model=MLPRegressor(), model__activation=tanh, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.186, test=-1.187) mse: (train=-2.654, test=-2.704) r2: (train=0.968, test=0.963) total time=  38.8s
# [CV 2/3] END model=MLPRegressor(), model__activation=tanh, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.149, test=-1.152) mse: (train=-2.551, test=-2.517) r2: (train=0.968, test=0.965) total time= 1.4min
# [CV 3/3] END model=MLPRegressor(), model__activation=tanh, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.123, test=-1.095) mse: (train=-2.439, test=-2.331) r2: (train=0.969, test=0.954) total time= 2.0min
# [CV 1/3] END model=MLPRegressor(), model__activation=relu, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.229, test=-1.208) mse: (train=-2.908, test=-2.876) r2: (train=0.965, test=0.961) total time=   8.5s
# [CV 2/3] END model=MLPRegressor(), model__activation=relu, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.239, test=-1.243) mse: (train=-3.095, test=-3.047) r2: (train=0.961, test=0.957) total time=   5.8s
# [CV 3/3] END model=MLPRegressor(), model__activation=relu, model__hidden_layer_sizes=(10,), model__max_iter=1000; mae: (train=-1.234, test=-1.199) mse: (train=-2.901, test=-2.733) r2: (train=0.963, test=0.946) total time=  26.9s
# [CV 1/3] END model=MLPRegressor(), model__activation=relu, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.166, test=-1.182) mse: (train=-2.579, test=-2.684) r2: (train=0.969, test=0.964) total time=  28.0s
# [CV 2/3] END model=MLPRegressor(), model__activation=relu, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.228, test=-1.229) mse: (train=-3.045, test=-2.995) r2: (train=0.961, test=0.958) total time=  24.4s
# [CV 3/3] END model=MLPRegressor(), model__activation=relu, model__hidden_layer_sizes=(50,), model__max_iter=1000; mae: (train=-1.189, test=-1.160) mse: (train=-2.706, test=-2.565) r2: (train=0.965, test=0.950) total time=  58.9s
# [CV 1/3] END model=MLPRegressor(), model__activation=relu, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.155, test=-1.172) mse: (train=-2.539, test=-2.641) r2: (train=0.969, test=0.964) total time=  31.9s
# [CV 2/3] END model=MLPRegressor(), model__activation=relu, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.168, test=-1.168) mse: (train=-2.625, test=-2.603) r2: (train=0.967, test=0.964) total time= 1.2min
# [CV 3/3] END model=MLPRegressor(), model__activation=relu, model__hidden_layer_sizes=(100,), model__max_iter=1000; mae: (train=-1.152, test=-1.121) mse: (train=-2.555, test=-2.425) r2: (train=0.967, test=0.952) total time=  50.8s
# [CV 1/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100; mae: (train=-1.072, test=-1.165) mse: (train=-2.191, test=-2.624) r2: (train=0.973, test=0.964) total time=   1.9s
# [CV 2/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100; mae: (train=-1.098, test=-1.153) mse: (train=-2.318, test=-2.561) r2: (train=0.970, test=0.964) total time=   1.1s
# [CV 3/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=100; mae: (train=-1.107, test=-1.113) mse: (train=-2.368, test=-2.402) r2: (train=0.970, test=0.953) total time=   1.5s
# [CV 1/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200; mae: (train=-0.989, test=-1.144) mse: (train=-1.878, test=-2.534) r2: (train=0.977, test=0.966) total time=   1.2s
# [CV 2/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200; mae: (train=-1.030, test=-1.116) mse: (train=-2.056, test=-2.436) r2: (train=0.974, test=0.966) total time=   2.2s
# [CV 3/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=200; mae: (train=-1.047, test=-1.089) mse: (train=-2.136, test=-2.306) r2: (train=0.973, test=0.955) total time=   2.9s
# [CV 1/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300; mae: (train=-0.947, test=-1.144) mse: (train=-1.731, test=-2.527) r2: (train=0.979, test=0.966) total time=   1.9s
# [CV 2/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300; mae: (train=-1.002, test=-1.110) mse: (train=-1.947, test=-2.422) r2: (train=0.975, test=0.966) total time=   3.1s
# [CV 3/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=300; mae: (train=-1.025, test=-1.086) mse: (train=-2.048, test=-2.296) r2: (train=0.974, test=0.955) total time=   4.4s
# [CV 1/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=500; mae: (train=-0.879, test=-1.150) mse: (train=-1.491, test=-2.545) r2: (train=0.982, test=0.966) total time=   3.1s
# [CV 2/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=500; mae: (train=-0.960, test=-1.108) mse: (train=-1.791, test=-2.422) r2: (train=0.977, test=0.966) total time=   5.1s
# [CV 3/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=1, model__n_estimators=500; mae: (train=-0.988, test=-1.086) mse: (train=-1.905, test=-2.294) r2: (train=0.976, test=0.955) total time=   7.1s
# [CV 1/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100; mae: (train=-1.070, test=-1.164) mse: (train=-2.184, test=-2.620) r2: (train=0.974, test=0.965) total time=   0.6s
# [CV 2/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100; mae: (train=-1.098, test=-1.154) mse: (train=-2.319, test=-2.566) r2: (train=0.970, test=0.964) total time=   1.2s
# [CV 3/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=100; mae: (train=-1.106, test=-1.112) mse: (train=-2.364, test=-2.399) r2: (train=0.970, test=0.953) total time=   1.6s
# [CV 1/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200; mae: (train=-0.989, test=-1.144) mse: (train=-1.878, test=-2.534) r2: (train=0.977, test=0.966) total time=   1.2s
# [CV 2/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200; mae: (train=-1.030, test=-1.118) mse: (train=-2.057, test=-2.443) r2: (train=0.974, test=0.966) total time=   2.2s
# [CV 3/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=200; mae: (train=-1.049, test=-1.089) mse: (train=-2.142, test=-2.308) r2: (train=0.973, test=0.955) total time=   3.2s
# [CV 1/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300; mae: (train=-0.948, test=-1.143) mse: (train=-1.735, test=-2.523) r2: (train=0.979, test=0.966) total time=   2.0s
# [CV 2/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300; mae: (train=-1.001, test=-1.113) mse: (train=-1.950, test=-2.432) r2: (train=0.975, test=0.966) total time=   3.2s
# [CV 3/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=300; mae: (train=-1.025, test=-1.086) mse: (train=-2.053, test=-2.295) r2: (train=0.974, test=0.955) total time=   4.4s
# [CV 1/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=500; mae: (train=-0.882, test=-1.147) mse: (train=-1.509, test=-2.533) r2: (train=0.982, test=0.966) total time=   3.2s
# [CV 2/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=500; mae: (train=-0.959, test=-1.113) mse: (train=-1.790, test=-2.439) r2: (train=0.977, test=0.966) total time=   5.7s
# [CV 3/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=3, model__n_estimators=500; mae: (train=-0.989, test=-1.085) mse: (train=-1.912, test=-2.293) r2: (train=0.975, test=0.955) total time=   7.4s
# [CV 1/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), model__learning_rate=0.05, model__max_depth=5, model__min_child_weight=5, model__n_estimators=100; mae: (train=-1.072, test=-1.165) mse: (train=-2.196, test=-2.626) r2: (train=0.973, test=0.964) total time=   0.8s
# [CV 2/3] END model=XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
# ...
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=11, model__weights=uniform; mae: (train=-1.049, test=-1.190) mse: (train=-2.165, test=-2.661) r2: (train=0.972, test=0.948) total time=   0.8s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=11, model__weights=distance; mae: (train=-0.000, test=-1.289) mse: (train=-0.000, test=-3.085) r2: (train=1.000, test=0.958) total time=   0.5s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=11, model__weights=distance; mae: (train=-0.000, test=-1.236) mse: (train=-0.000, test=-2.915) r2: (train=1.000, test=0.959) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=11, model__weights=distance; mae: (train=-0.000, test=-1.189) mse: (train=-0.000, test=-2.658) r2: (train=1.000, test=0.948) total time=   0.8s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=13, model__weights=uniform; mae: (train=-1.078, test=-1.287) mse: (train=-2.260, test=-3.060) r2: (train=0.973, test=0.959) total time=   0.6s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=13, model__weights=uniform; mae: (train=-1.068, test=-1.230) mse: (train=-2.225, test=-2.877) r2: (train=0.972, test=0.960) total time=   0.7s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=13, model__weights=uniform; mae: (train=-1.062, test=-1.179) mse: (train=-2.209, test=-2.615) r2: (train=0.972, test=0.949) total time=   0.9s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=13, model__weights=distance; mae: (train=-0.000, test=-1.283) mse: (train=-0.000, test=-3.044) r2: (train=1.000, test=0.959) total time=   0.5s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=13, model__weights=distance; mae: (train=-0.000, test=-1.226) mse: (train=-0.000, test=-2.871) r2: (train=1.000, test=0.960) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=13, model__weights=distance; mae: (train=-0.000, test=-1.178) mse: (train=-0.000, test=-2.613) r2: (train=1.000, test=0.949) total time=   0.8s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=15, model__weights=uniform; mae: (train=-1.095, test=-1.279) mse: (train=-2.317, test=-3.024) r2: (train=0.972, test=0.959) total time=   0.6s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=15, model__weights=uniform; mae: (train=-1.080, test=-1.226) mse: (train=-2.268, test=-2.856) r2: (train=0.971, test=0.960) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=15, model__weights=uniform; mae: (train=-1.073, test=-1.172) mse: (train=-2.248, test=-2.580) r2: (train=0.971, test=0.949) total time=   0.9s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=15, model__weights=distance; mae: (train=-0.000, test=-1.274) mse: (train=-0.000, test=-3.007) r2: (train=1.000, test=0.959) total time=   0.6s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=15, model__weights=distance; mae: (train=-0.000, test=-1.222) mse: (train=-0.000, test=-2.848) r2: (train=1.000, test=0.960) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=euclidean, model__n_neighbors=15, model__weights=distance; mae: (train=-0.000, test=-1.170) mse: (train=-0.000, test=-2.578) r2: (train=1.000, test=0.949) total time=   0.9s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=3, model__weights=uniform; mae: (train=-0.817, test=-1.391) mse: (train=-1.447, test=-3.598) r2: (train=0.982, test=0.951) total time=   0.4s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=3, model__weights=uniform; mae: (train=-0.831, test=-1.373) mse: (train=-1.451, test=-3.567) r2: (train=0.982, test=0.950) total time=   0.5s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=3, model__weights=uniform; mae: (train=-0.838, test=-1.311) mse: (train=-1.468, test=-3.234) r2: (train=0.981, test=0.936) total time=   0.7s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=3, model__weights=distance; mae: (train=-0.000, test=-1.391) mse: (train=-0.000, test=-3.602) r2: (train=1.000, test=0.951) total time=   0.4s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=3, model__weights=distance; mae: (train=-0.000, test=-1.376) mse: (train=-0.000, test=-3.582) r2: (train=1.000, test=0.950) total time=   0.5s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=3, model__weights=distance; mae: (train=-0.000, test=-1.314) mse: (train=-0.000, test=-3.254) r2: (train=1.000, test=0.936) total time=   0.7s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=5, model__weights=uniform; mae: (train=-0.931, test=-1.313) mse: (train=-1.788, test=-3.232) r2: (train=0.978, test=0.956) total time=   0.4s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=5, model__weights=uniform; mae: (train=-0.936, test=-1.286) mse: (train=-1.799, test=-3.166) r2: (train=0.977, test=0.956) total time=   0.6s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=5, model__weights=uniform; mae: (train=-0.941, test=-1.239) mse: (train=-1.810, test=-2.904) r2: (train=0.977, test=0.943) total time=   0.9s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=5, model__weights=distance; mae: (train=-0.000, test=-1.314) mse: (train=-0.000, test=-3.233) r2: (train=1.000, test=0.956) total time=   0.5s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=5, model__weights=distance; mae: (train=-0.000, test=-1.288) mse: (train=-0.000, test=-3.172) r2: (train=1.000, test=0.956) total time=   0.6s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=5, model__weights=distance; mae: (train=-0.000, test=-1.241) mse: (train=-0.000, test=-2.918) r2: (train=1.000, test=0.943) total time=   0.9s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=7, model__weights=uniform; mae: (train=-0.986, test=-1.283) mse: (train=-1.966, test=-3.091) r2: (train=0.976, test=0.958) total time=   0.6s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=7, model__weights=uniform; mae: (train=-0.988, test=-1.249) mse: (train=-1.967, test=-2.996) r2: (train=0.975, test=0.958) total time=   0.9s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=7, model__weights=uniform; mae: (train=-0.989, test=-1.202) mse: (train=-1.978, test=-2.747) r2: (train=0.975, test=0.946) total time=   0.9s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=7, model__weights=distance; mae: (train=-0.000, test=-1.282) mse: (train=-0.000, test=-3.086) r2: (train=1.000, test=0.958) total time=   0.5s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=7, model__weights=distance; mae: (train=-0.000, test=-1.249) mse: (train=-0.000, test=-2.999) r2: (train=1.000, test=0.958) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=7, model__weights=distance; mae: (train=-0.000, test=-1.204) mse: (train=-0.000, test=-2.758) r2: (train=1.000, test=0.946) total time=   0.9s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=9, model__weights=uniform; mae: (train=-1.019, test=-1.261) mse: (train=-2.085, test=-2.992) r2: (train=0.975, test=0.959) total time=   0.6s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=9, model__weights=uniform; mae: (train=-1.017, test=-1.231) mse: (train=-2.075, test=-2.893) r2: (train=0.974, test=0.960) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=9, model__weights=uniform; mae: (train=-1.017, test=-1.187) mse: (train=-2.073, test=-2.680) r2: (train=0.973, test=0.947) total time=   1.0s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=9, model__weights=distance; mae: (train=-0.000, test=-1.259) mse: (train=-0.000, test=-2.985) r2: (train=1.000, test=0.960) total time=   0.6s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=9, model__weights=distance; mae: (train=-0.000, test=-1.229) mse: (train=-0.000, test=-2.893) r2: (train=1.000, test=0.960) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=9, model__weights=distance; mae: (train=-0.000, test=-1.187) mse: (train=-0.000, test=-2.683) r2: (train=1.000, test=0.947) total time=   1.0s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=11, model__weights=uniform; mae: (train=-1.042, test=-1.250) mse: (train=-2.157, test=-2.949) r2: (train=0.974, test=0.960) total time=   0.6s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=11, model__weights=uniform; mae: (train=-1.036, test=-1.220) mse: (train=-2.148, test=-2.844) r2: (train=0.973, test=0.960) total time=   0.7s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=11, model__weights=uniform; mae: (train=-1.036, test=-1.173) mse: (train=-2.142, test=-2.617) r2: (train=0.973, test=0.949) total time=   1.1s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=11, model__weights=distance; mae: (train=-0.000, test=-1.247) mse: (train=-0.000, test=-2.938) r2: (train=1.000, test=0.960) total time=   0.6s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=11, model__weights=distance; mae: (train=-0.000, test=-1.217) mse: (train=-0.000, test=-2.841) r2: (train=1.000, test=0.960) total time=   0.9s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=11, model__weights=distance; mae: (train=-0.000, test=-1.172) mse: (train=-0.000, test=-2.620) r2: (train=1.000, test=0.948) total time=   1.1s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=13, model__weights=uniform; mae: (train=-1.063, test=-1.244) mse: (train=-2.235, test=-2.920) r2: (train=0.973, test=0.960) total time=   0.6s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=13, model__weights=uniform; mae: (train=-1.051, test=-1.212) mse: (train=-2.197, test=-2.802) r2: (train=0.972, test=0.961) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=13, model__weights=uniform; mae: (train=-1.050, test=-1.161) mse: (train=-2.191, test=-2.571) r2: (train=0.972, test=0.949) total time=   1.1s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=13, model__weights=distance; mae: (train=-0.000, test=-1.241) mse: (train=-0.000, test=-2.906) r2: (train=1.000, test=0.961) total time=   0.6s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=13, model__weights=distance; mae: (train=-0.000, test=-1.209) mse: (train=-0.000, test=-2.797) r2: (train=1.000, test=0.961) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=13, model__weights=distance; mae: (train=-0.000, test=-1.161) mse: (train=-0.000, test=-2.574) r2: (train=1.000, test=0.949) total time=   1.3s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=15, model__weights=uniform; mae: (train=-1.082, test=-1.239) mse: (train=-2.301, test=-2.890) r2: (train=0.972, test=0.961) total time=   0.7s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=15, model__weights=uniform; mae: (train=-1.066, test=-1.207) mse: (train=-2.248, test=-2.769) r2: (train=0.971, test=0.961) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=15, model__weights=uniform; mae: (train=-1.061, test=-1.157) mse: (train=-2.226, test=-2.551) r2: (train=0.971, test=0.950) total time=   1.2s
# [CV 1/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=15, model__weights=distance; mae: (train=-0.000, test=-1.235) mse: (train=-0.000, test=-2.874) r2: (train=1.000, test=0.961) total time=   0.7s
# [CV 2/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=15, model__weights=distance; mae: (train=-0.000, test=-1.203) mse: (train=-0.000, test=-2.762) r2: (train=1.000, test=0.961) total time=   0.8s
# [CV 3/3] END model=KNeighborsRegressor(), model__leaf_size=50, model__metric=manhattan, model__n_neighbors=15, model__weights=distance; mae: (train=-0.000, test=-1.156) mse: (train=-0.000, test=-2.551) r2: (train=1.000, test=0.950) total time=   1.3s
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#              estimator=Pipeline(steps=[('preprocesing', MinMaxScaler()),
#                                        ('model',
#                                         [('RandomForestRegressor',
#                                           RandomForestRegressor()),
#                                          ('LinearRegression',
#                                           LinearRegression()),
#                                          ('Ridge', Ridge()), ('Lasso', Lasso()),
#                                          ('SVR', SVR()),
#                                          ('MLPRegressor', MLPRegressor()),
#                                          ('XGBoost',
#                                           XGBRegressor(b...
#                           'model__leaf_size': [10, 20, 30, 40, 50],
#                           'model__metric': ['euclidean', 'manhattan'],
#                           'model__n_neighbors': array([ 3,  5,  7,  9, 11, 13, 15]),
#                           'model__weights': ['uniform', 'distance']}],
#              refit='r2', return_train_score=True,
#              scoring={'mae': make_scorer(mean_absolute_error, greater_is_better=False),
#                       'mse': make_scorer(mean_squared_error, greater_is_better=False),
#                       'r2': make_scorer(r2_score)},
#              verbose=3)

# %%
#Imprimindo os melhores parâmetros e métricas de avaliação
print("Melhores parâmetros: ", grid.best_params_)
print("Melhor métrica R2: ", grid.best_score_)
# Out:
# Melhores parâmetros:  {'model': XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=10, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...), 'model__learning_rate': 0.05, 'model__max_depth': 5, 'model__min_child_weight': 10, 'model__n_estimators': 300}
# Melhor métrica (MSE):  0.9623729649942359

# %% [markdown]
# >**Comentário**: O modelo que apresentou o melhor resultado foi o Gradient Boosting, com o coeficiente de determinação no valor de 0.96.

# %% [markdown]
# ##### Aplicação do modelo e verificação das métricas na base de teste.

# %%
# Fazendo as previsões com o melhor modelo
best_model = grid.best_estimator_
Y_pred = best_model.predict(X_test)

# %%
# Calculando as métricas de avaliação no conjunto de teste
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)
mae = mean_absolute_error(Y_test, Y_pred)

print("MSE: ", mse)
print("R2: ", r2)
print("MAE: ", mae)
# Out:
# MSE:  2.403806302011443
# R2:  0.9632806703548327
# MAE:  1.1223322776778635

# %%
print(Y_test)
print(Y_pred)
# Out:
# [17.93 16.92 15.82 ... -1.52 -3.09 -2.59]
# [18.48343   16.500612  15.510152  ... -1.5385993 -3.657398  -5.4520445]

# %%
#gravação do modelo treinado
joblib.dump(best_model, '../models/best_model_temp_2.joblib')
# Out:
# ['../models/best_model_temp_2.joblib']

# %%
#Carregando o modelo treinado
modelo = joblib.load('../models/best_model_temp_2.joblib')

# %%
Y_predict = modelo.predict(X_test)

# %%
# Gráfico para visualizar os valores reais e os previstos pelo modelo
import matplotlib.pyplot as plt
plt.plot(Y_test)
plt.plot(Y_predict)
plt.legend(["Teste","Previsão"])
plt.show()

# %%
#Tabela para a visualização dos valores reais e os previstos
resultados = {'Real':Y_test, 'Previsao':Y_predict}
df_resultado = pd.DataFrame(resultados)
df_resultado
# Out:
#         Real   Previsao
# 0      17.93  18.483431
# 1      16.92  16.500612
# 2      15.82  15.510152
# 3      15.02  14.046124
# 4      14.14  13.906175
# ...      ...        ...
# 14013  -0.08  -1.070870
# 14014  -1.03  -3.177981
# 14015  -1.52  -1.538599
# 14016  -3.09  -3.657398
# 14017  -2.59  -5.452044
#
# [14018 rows x 2 columns]
